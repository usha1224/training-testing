# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Gopi Raju\\Desktop\\remote internship'

# %%
os.chdir("C:\\Users\\Gopi Raju\\Desktop\\remote internship\\dataset")
os.getcwd()
# Out:
# 'C:\\Users\\Gopi Raju\\Desktop\\remote internship\\dataset'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv("cereal.csv")
data
# Out:
#                           name mfr type  calories  protein  fat  sodium  \
# 0                    100% Bran   N    C        70      4.0  1.0     130
# 1            100% Natural Bran   Q    C       120      3.0  5.0      15
# 2                     All-Bran   K    C        70      4.0  1.0     260
# 3    All-Bran with Extra Fiber   K    C        50      4.0  0.0     140
# 4               Almond Delight   R    C       110      2.0  2.0     200
# ..                         ...  ..  ...       ...      ...  ...     ...
# 96                        Trix   G    C       110      1.0  1.0     140
# 97                Waffle Crisp   K    C       110      2.0  1.0     165
# 98                  Wheat Chex   R    C       100      3.0  1.0     230
# 99                    Wheaties   G    C       100      3.0  1.0     200
# 100        Wheaties Honey Gold   G    C       110      2.0  1.0     200
#
#      fiber  carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     10.0    5.0     6.0     280        25      3     1.0  0.33  68.402973
# 1      2.0    8.0     8.0     135         0      3     1.0  1.00  33.983679
# 2      9.0    7.0     5.0     320        25      3     1.0  0.33  59.425505
# 3     14.0    8.0     0.0     330        25      3     1.0  0.50  93.704912
# 4      1.0   14.0     8.0      -1        25      3     1.0  0.75  34.384843
# ..     ...    ...     ...     ...       ...    ...     ...   ...        ...
# 96     0.0   13.0    12.0      25        25      2     1.0  1.00  27.753301
# 97     3.2   28.0     2.0      75        25      2     1.0  1.00  34.325100
# 98     3.0   17.0     3.0     115        25      1     1.0  0.67  49.787445
# 99     3.0   17.0     3.0     110        25      1     1.0  1.00  51.592193
# 100    1.0   16.0     8.0      60        25      1     1.0  0.75  36.187559
#
# [101 rows x 16 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f00231d49596> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
#
# NameError: name 'x' is not defined

# %%
x=data.iloc[:,0:3].values

y=data.iloc[:,3].values
# Out:
#   File "<ipython-input-5-5911d0549ecf>", line 1
#     //Step 4: Splitting Dataset in to Independent variable and Dependent variable
#      ^
# SyntaxError: invalid syntax

# %%
x=data.iloc[:,0:3].values

y=data.iloc[:,3].values

# %%
x,y
# Out:
# (array([['100% Bran', 'N', 'C'],
#         ['100% Natural Bran', 'Q', 'C'],
#         ['All-Bran', 'K', 'C'],
#         ['All-Bran with Extra Fiber', 'K', 'C'],
#         ['Almond Delight', 'R', 'C'],
#         ['Amarnath', 'R', 'C'],
#         ['Apple Cinnamon Cheerios', 'G', 'C'],
#         ['Apple Jacks', 'K', 'C'],
#         ['Barley', 'G', 'C'],
#         ['Basic 4', 'G', 'C'],
#         ['Bran Chex', 'R', 'C'],
#         ['Bran Flakes', 'P', 'C'],
#         ['Bread Wheat', 'A', 'C'],
#         ['Canary Grass', 'A', 'H'],
#         ["Cap'n'Crunch", 'Q', 'C'],
#         ['Cheerios', 'G', 'C'],
#         ['Chia Seeds', 'A', 'C'],
#         ['Cinnamon Toast Crunch', 'G', 'C'],
#         ['Clusters', 'G', 'C'],
#         ['Cocoa Puffs', 'G', 'C'],
#         ['Corn Chex', 'R', 'C'],
#         ['Corn Flakes', 'K', 'C'],
#         ['Corn Pops', 'K', 'C'],
#         ['Count Chocula', 'G', 'C'],
#         ["Cracklin' Oat Bran", 'K', 'C'],
#         ['Cream of Wheat (Quick)', 'N', 'H'],
#         ['Crispix', 'K', 'C'],
#         ['Crispy Wheat & Raisins', 'G', 'C'],
#         ['Crunchy Pecan', 'A', 'C'],
#         ['Double Chex', 'R', 'C'],
#         ['Durum', 'Q', 'C'],
#         ['Fonio', 'R', 'C'],
#         ['Froot Loops', 'K', 'C'],
#         ['Frosted Flakes', 'K', 'C'],
#         ['Frosted Mini-Wheats', 'K', 'C'],
#         ['Fruit & Fibre Dates; Walnuts; and Oats', 'P', 'C'],
#         ['Fruitful Bran', 'K', 'C'],
#         ['Fruity Pebbles', 'P', 'C'],
#         ['Golden Crisp', 'P', 'C'],
#         ['Golden Grahams', 'G', 'C'],
#         ['Grape Nuts Flakes', 'P', 'C'],
#         ['Grape-Nuts', 'P', 'C'],
#         ['Great Grains Pecan', 'P', 'C'],
#         ['Honey Comb', 'N', 'C'],
#         ['Honey Graham Ohs', 'Q', 'C'],
#         ['Honey Nut Cheerios', 'G', 'C'],
#         ['Honey-comb', 'P', 'C'],
#         ['Just Right Crunchy  Nuggets', 'K', 'C'],
#         ['Just Right Fruit & Nut', 'K', 'C'],
#         ['Kix', 'G', 'C'],
#         ['Life', 'Q', 'C'],
#         ['Lucky Charms', 'G', 'C'],
#         ['Macaroni', 'G', 'C'],
#         ['Maypo', 'A', 'H'],
#         ['Millet', 'G', 'C'],
#         ['Muesli Raisins; Dates; & Almonds', 'R', 'C'],
#         ['Muesli Raisins; Peaches; & Pecans', 'R', 'C'],
#         ['Mueslix Crispy Blend', 'K', 'C'],
#         ['Multi-Grain Cheerios', 'G', 'C'],
#         ['Nut&Honey Crunch', 'K', 'C'],
#         ['Nutri-Grain Almond-Raisin', 'K', 'C'],
#         ['Nutri-grain Wheat', 'K', 'C'],
#         ['Oatmeal Raisin Crisp', 'G', 'C'],
#         ['Pitseed Goosefeet', 'A', 'C'],
#         ['Post Nat. Raisin Bran', 'P', 'C'],
#         ['Product 19', 'K', 'C'],
#         ['Proso Millet', 'K', 'C'],
#         ['Puffed Rice', 'Q', 'C'],
#         ['Puffed Wheat', 'Q', 'C'],
#         ['Quaker Oat Squares', 'Q', 'C'],
#         ['Quaker Oatmeal', 'Q', 'H'],
#         ['Quinoa', 'N', 'C'],
#         ['Ragi', 'P', 'H'],
#         ['Raisin Bran', 'K', 'C'],
#         ['Raisin Nut Bran', 'G', 'C'],
#         ['Raisin Squares', 'K', 'C'],
#         ['Rice Chex', 'R', 'C'],
#         ['Rice Krispies', 'K', 'C'],
#         ['Ruskets', 'R', 'C'],
#         ['Rye', 'A', 'C'],
#         ['Sago', 'R', 'H'],
#         ['Semoline', 'A', 'C'],
#         ['Shredded Wheat', 'N', 'C'],
#         ["Shredded Wheat 'n'Bran", 'N', 'C'],
#         ['Shredded Wheat spoon size', 'N', 'C'],
#         ['Smacks', 'K', 'C'],
#         ['Sorghum', 'G', 'C'],
#         ['Special K', 'K', 'C'],
#         ['Spelt', 'G', 'C'],
#         ['Strawberry Fruit Wheats', 'N', 'C'],
#         ['Teff', 'K', 'C'],
#         ['Total Corn Flakes', 'G', 'C'],
#         ['Total Raisin Bran', 'G', 'C'],
#         ['Total Whole Grain', 'G', 'C'],
#         ['Triples', 'G', 'C'],
#         ['Triticals', 'P', 'C'],
#         ['Trix', 'G', 'C'],
#         ['Waffle Crisp', 'K', 'C'],
#         ['Wheat Chex', 'R', 'C'],
#         ['Wheaties', 'G', 'C'],
#         ['Wheaties Honey Gold', 'G', 'C']], dtype=object),
#  array([ 70, 120,  70,  50, 110, 165, 110, 110, 193, 130,  90,  90,  82,
#         150, 120, 110, 130, 120, 110, 110, 110, 100, 110, 110, 110, 100,
#         110, 100, 210, 100, 160, 220, 110, 110, 100, 120, 120, 110, 100,
#         110, 100, 110, 120, 150, 120, 110, 110, 110, 140, 110, 100, 110,
#         250, 100, 207, 150, 150, 160, 100, 120, 140,  90, 130,  47, 120,
#         100, 100,  50,  50, 100, 100, 160, 100, 120, 100,  90, 110, 110,
#          95, 250,  90, 140,  80,  90,  90, 110, 155, 110, 120,  90, 155,
#         110, 140, 100, 110, 140, 110, 110, 100, 100, 110], dtype=int64))

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
# array([['Oatmeal Raisin Crisp', 'G', 'C'],
#        ['All-Bran with Extra Fiber', 'K', 'C'],
#        ['Quinoa', 'N', 'C'],
#        ['Honey Nut Cheerios', 'G', 'C'],
#        ['Just Right Fruit & Nut', 'K', 'C'],
#        ['Apple Cinnamon Cheerios', 'G', 'C'],
#        ['Wheaties Honey Gold', 'G', 'C'],
#        ['Shredded Wheat', 'N', 'C'],
#        ['Rice Chex', 'R', 'C'],
#        ['Nutri-Grain Almond-Raisin', 'K', 'C'],
#        ['Sago', 'R', 'H'],
#        ['Total Corn Flakes', 'G', 'C'],
#        ['Puffed Wheat', 'Q', 'C'],
#        ['Lucky Charms', 'G', 'C'],
#        ['Crispy Wheat & Raisins', 'G', 'C'],
#        ['Clusters', 'G', 'C'],
#        ['Muesli Raisins; Peaches; & Pecans', 'R', 'C'],
#        ['Pitseed Goosefeet', 'A', 'C'],
#        ['Raisin Nut Bran', 'G', 'C'],
#        ['100% Natural Bran', 'Q', 'C'],
#        ['Nutri-grain Wheat', 'K', 'C'],
#        ['Great Grains Pecan', 'P', 'C'],
#        ['Grape-Nuts', 'P', 'C'],
#        ['Almond Delight', 'R', 'C'],
#        ['Cheerios', 'G', 'C'],
#        ['Cinnamon Toast Crunch', 'G', 'C'],
#        ['Grape Nuts Flakes', 'P', 'C'],
#        ['Golden Crisp', 'P', 'C'],
#        ['Amarnath', 'R', 'C'],
#        ['Total Raisin Bran', 'G', 'C'],
#        ['Nut&Honey Crunch', 'K', 'C'],
#        ['100% Bran', 'N', 'C'],
#        ['Frosted Mini-Wheats', 'K', 'C'],
#        ['Crunchy Pecan', 'A', 'C'],
#        ['Life', 'Q', 'C'],
#        ['Bran Flakes', 'P', 'C'],
#        ['Fruit & Fibre Dates; Walnuts; and Oats', 'P', 'C'],
#        ['Count Chocula', 'G', 'C'],
#        ['Macaroni', 'G', 'C'],
#        ['Bran Chex', 'R', 'C'],
#        ['Fonio', 'R', 'C'],
#        ['Proso Millet', 'K', 'C'],
#        ['Mueslix Crispy Blend', 'K', 'C'],
#        ['Rye', 'A', 'C'],
#        ['Smacks', 'K', 'C'],
#        ['Froot Loops', 'K', 'C'],
#        ['Shredded Wheat spoon size', 'N', 'C'],
#        ["Cap'n'Crunch", 'Q', 'C'],
#        ['Teff', 'K', 'C'],
#        ['Cocoa Puffs', 'G', 'C'],
#        ['Double Chex', 'R', 'C'],
#        ['Kix', 'G', 'C'],
#        ['Wheat Chex', 'R', 'C'],
#        ['Wheaties', 'G', 'C'],
#        ['Quaker Oat Squares', 'Q', 'C'],
#        ['Corn Chex', 'R', 'C'],
#        ['Triticals', 'P', 'C'],
#        ['Ragi', 'P', 'H'],
#        ['Rice Krispies', 'K', 'C'],
#        ['Cream of Wheat (Quick)', 'N', 'H'],
#        ['Fruity Pebbles', 'P', 'C'],
#        ['Semoline', 'A', 'C'],
#        ['Honey-comb', 'P', 'C'],
#        ['Golden Grahams', 'G', 'C'],
#        ['Product 19', 'K', 'C'],
#        ['Multi-Grain Cheerios', 'G', 'C'],
#        ['Bread Wheat', 'A', 'C'],
#        ['Strawberry Fruit Wheats', 'N', 'C'],
#        ['Spelt', 'G', 'C'],
#        ['Quaker Oatmeal', 'Q', 'H'],
#        ['Special K', 'K', 'C'],
#        ['Fruitful Bran', 'K', 'C'],
#        ['Corn Flakes', 'K', 'C'],
#        ["Shredded Wheat 'n'Bran", 'N', 'C'],
#        ['Basic 4', 'G', 'C'],
#        ['Waffle Crisp', 'K', 'C'],
#        ['Puffed Rice', 'Q', 'C'],
#        ['Post Nat. Raisin Bran', 'P', 'C'],
#        ['Just Right Crunchy  Nuggets', 'K', 'C'],
#        ['Honey Graham Ohs', 'Q', 'C']], dtype=object)

# %%
x_test
# Out:
# array([['Crispix', 'K', 'C'],
#        ['Sorghum', 'G', 'C'],
#        ['All-Bran', 'K', 'C'],
#        ['Muesli Raisins; Dates; & Almonds', 'R', 'C'],
#        ['Raisin Squares', 'K', 'C'],
#        ['Triples', 'G', 'C'],
#        ['Chia Seeds', 'A', 'C'],
#        ['Raisin Bran', 'K', 'C'],
#        ['Millet', 'G', 'C'],
#        ['Trix', 'G', 'C'],
#        ['Maypo', 'A', 'H'],
#        ['Total Whole Grain', 'G', 'C'],
#        ['Ruskets', 'R', 'C'],
#        ['Canary Grass', 'A', 'H'],
#        ['Apple Jacks', 'K', 'C'],
#        ['Durum', 'Q', 'C'],
#        ['Corn Pops', 'K', 'C'],
#        ["Cracklin' Oat Bran", 'K', 'C'],
#        ['Frosted Flakes', 'K', 'C'],
#        ['Barley', 'G', 'C'],
#        ['Honey Comb', 'N', 'C']], dtype=object)

# %%
y_train
# Out:
# array([130,  50, 160, 110, 140, 110, 110,  80, 110, 140,  90, 110,  50,
#        110, 100, 110, 150,  47, 100, 120,  90, 120, 110, 110, 110, 120,
#        100, 100, 165, 140, 120,  70, 100, 210, 100,  90, 120, 110, 250,
#         90, 220, 100, 160, 250, 110, 110,  90, 120, 155, 110, 100, 110,
#        100, 100, 100, 110, 140, 100, 110, 100, 110, 140, 110, 110, 100,
#        100,  82,  90, 120, 100, 110, 120, 100,  90, 130, 110,  50, 120,
#        110, 120], dtype=int64)

# %%
y_test
# Out:
# array([110, 155,  70, 150,  90, 110, 130, 120, 207, 110, 100, 100,  95,
#        150, 110, 160, 110, 110, 110, 193, 150], dtype=int64)
