# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Gopi Raju\\Desktop\\remote internship\\dataset'

# %%
os.chdir("C:\\Users\\Gopi Raju\\Desktop\\remote internship\\dataset")
os.getcwd()
# Out:
# 'C:\\Users\\Gopi Raju\\Desktop\\remote internship\\dataset'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
data=pd.read_csv("cereal.csv")
data
# Out:
#                           name mfr type  calories  protein  fat  sodium  \
# 0                    100% Bran   N    C        70      4.0  1.0     130
# 1            100% Natural Bran   Q    C       120      3.0  5.0      15
# 2                     All-Bran   K    C        70      4.0  1.0     260
# 3    All-Bran with Extra Fiber   K    C        50      4.0  0.0     140
# 4               Almond Delight   R    C       110      2.0  2.0     200
# ..                         ...  ..  ...       ...      ...  ...     ...
# 96                        Trix   G    C       110      1.0  1.0     140
# 97                Waffle Crisp   K    C       110      2.0  1.0     165
# 98                  Wheat Chex   R    C       100      3.0  1.0     230
# 99                    Wheaties   G    C       100      3.0  1.0     200
# 100        Wheaties Honey Gold   G    C       110      2.0  1.0     200
#
#      fiber  carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     10.0    5.0     6.0     280        25      3     1.0  0.33  68.402973
# 1      2.0    8.0     8.0     135         0      3     1.0  1.00  33.983679
# 2      9.0    7.0     5.0     320        25      3     1.0  0.33  59.425505
# 3     14.0    8.0     0.0     330        25      3     1.0  0.50  93.704912
# 4      1.0   14.0     8.0      -1        25      3     1.0  0.75  34.384843
# ..     ...    ...     ...     ...       ...    ...     ...   ...        ...
# 96     0.0   13.0    12.0      25        25      2     1.0  1.00  27.753301
# 97     3.2   28.0     2.0      75        25      2     1.0  1.00  34.325100
# 98     3.0   17.0     3.0     115        25      1     1.0  0.67  49.787445
# 99     3.0   17.0     3.0     110        25      1     1.0  1.00  51.592193
# 100    1.0   16.0     8.0      60        25      1     1.0  0.75  36.187559
#
# [101 rows x 16 columns]

# %%
o_fat=data['fat']

# %%
o_fat
# Out:
# 0      1.0
# 1      5.0
# 2      1.0
# 3      0.0
# 4      2.0
#       ...
# 96     1.0
# 97     1.0
# 98     1.0
# 99     1.0
# 100    1.0
# Name: fat, Length: 101, dtype: float64

# %%
temp=data['sodium']

# %%
temp
# Out:
# 0      130
# 1       15
# 2      260
# 3      140
# 4      200
#       ...
# 96     140
# 97     165
# 98     230
# 99     200
# 100    200
# Name: sodium, Length: 101, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
ax=plt.plot(temp,o_fat,'o')
plt.ylabel('fat')
plt.xlabel('sodium')
# Out:
# Text(0.5, 0, 'sodium')

# %%
import statsmodels.api as sm
model=sm.OLS(o_fat,temp).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    fat   R-squared (uncentered):                   0.410
# Model:                            OLS   Adj. R-squared (uncentered):              0.405
# Method:                 Least Squares   F-statistic:                              69.62
# Date:                Mon, 18 May 2020   Prob (F-statistic):                    4.12e-13
# Time:                        10:59:07   Log-Likelihood:                         -160.71
# No. Observations:                 101   AIC:                                      323.4
# Df Residuals:                     100   BIC:                                      326.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sodium         0.0058      0.001      8.344      0.000       0.004       0.007
# ==============================================================================
# Omnibus:                       14.820   Durbin-Watson:                   1.588
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               18.594
# Skew:                           0.763   Prob(JB):                     9.17e-05
# Kurtosis:                       4.447   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import seaborn as sns
sns.pairplot(data)

# %%
sns.distplot(data['sodium'])

# %%
x=data['fat']
y=data['sodium']

# %%
x,y
# Out:
# (0      1.0
#  1      5.0
#  2      1.0
#  3      0.0
#  4      2.0
#        ...
#  96     1.0
#  97     1.0
#  98     1.0
#  99     1.0
#  100    1.0
#  Name: fat, Length: 101, dtype: float64,
#  0      130
#  1       15
#  2      260
#  3      140
#  4      200
#        ...
#  96     140
#  97     165
#  98     230
#  99     200
#  100    200
#  Name: sodium, Length: 101, dtype: int64)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=1)

# %%
x_train
# Out:
# 23    1.0
# 34    0.0
# 87    0.0
# 56    3.0
# 69    1.0
# 15    2.0
# 84    0.0
# 41    0.0
# 45    1.0
# 92    1.0
# 26    0.0
# 99    1.0
# 43    1.7
# 59    1.0
# 24    3.0
# 4     2.0
# 62    2.0
# 89    0.0
# 49    1.0
# 21    0.0
# 88    1.0
# 3     0.0
# 96    1.0
# 30    1.5
# 47    1.0
# 77    0.0
# 8     1.0
# 60    2.0
# 0     1.0
# 91    1.0
# 57    2.0
# 22    0.0
# 61    0.0
# 63    3.0
# 7     0.0
# 97    1.0
# 13    1.5
# 68    0.0
# 86    1.5
# 14    2.0
# 29    0.0
# 28    2.0
# 11    0.0
# 18    2.0
# 20    0.0
# 50    2.0
# 25    0.0
# 6     2.0
# 71    3.0
# 76    0.0
# 1     5.0
# 16    2.0
# 64    1.0
# 79    2.4
# 5     3.5
# 75    0.0
# 9     2.0
# 72    3.0
# 12    1.1
# 37    1.0
# Name: fat, dtype: float64

# %%
x_test
# Out:
# 94     1.0
# 78     1.4
# 17     3.0
# 100    1.0
# 36     0.0
# 85     1.0
# 55     3.0
# 83     0.0
# 82     0.0
# 52     1.0
# 95     1.0
# 44     2.0
# 31     1.6
# 93     1.0
# 65     0.0
# 35     2.0
# 66     1.0
# 70     2.0
# 81     2.0
# 80     1.5
# 33     0.0
# 32     1.0
# 40     1.0
# 39     1.0
# 38     0.0
# 46     0.0
# 42     3.0
# 10     1.0
# 2      1.0
# 54     1.7
# 67     0.0
# 73     1.0
# 19     1.0
# 27     1.0
# 48     1.0
# 58     1.0
# 90     1.5
# 98     1.0
# 53     1.0
# 51     1.0
# 74     2.0
# Name: fat, dtype: float64

# %%
y_train
# Out:
# 23    180
# 34      0
# 87    230
# 56    150
# 69    135
# 15    290
# 84      0
# 41    170
# 45    250
# 92    190
# 26    220
# 99    200
# 43    156
# 59    190
# 24    140
# 4     200
# 62    170
# 89     15
# 49    260
# 21    290
# 88    140
# 3     140
# 96    140
# 30    100
# 47    170
# 77    290
# 8       0
# 60    220
# 0     130
# 91    200
# 57    150
# 22     90
# 61    170
# 63     70
# 7     125
# 97    165
# 13    170
# 68      0
# 86      0
# 14    220
# 29    190
# 28    186
# 11    210
# 18    140
# 20    280
# 50    150
# 25     80
# 6     180
# 71    200
# 76    240
# 1      15
# 16    100
# 64    200
# 79      0
# 5     175
# 75      0
# 9     210
# 72    100
# 12    144
# 37    135
# Name: sodium, dtype: int64

# %%
y_test
# Out:
# 94     250
# 78     135
# 17     210
# 100    200
# 36     240
# 85      70
# 55      95
# 83       0
# 82       0
# 52     150
# 95     221
# 44     220
# 31       0
# 93     200
# 65     320
# 35     160
# 66       0
# 70       0
# 81     130
# 80     250
# 33     200
# 32     125
# 40     140
# 39     280
# 38      45
# 46     180
# 42      75
# 10     200
# 2      260
# 54       0
# 67       0
# 73     210
# 19     180
# 27     140
# 48     170
# 58     220
# 90       0
# 98     230
# 53       0
# 51     180
# 74     140
# Name: sodium, dtype: int64
